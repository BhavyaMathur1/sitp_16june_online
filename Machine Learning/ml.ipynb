# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\HP\AppData\Local\Packages\5319275A.51895FA4EA97F_cv1g1gvanyjgm\LocalState\sessions\01A1B9BDB8A069AEFD8D2D9C9DFA298DF7304A02\transfers\2025-27\Old_Bikes_encoded.csv")
df
# Out:
#          price  kms_driven  owner  age  power  brand
# 0      35000.0     17654.0      1  3.0  110.0      0
# 1     119900.0     11000.0      1  4.0  350.0      1
# 2     600000.0       110.0      1  8.0  675.0      2
# 3      65000.0     16329.0      1  4.0  180.0      0
# 4      80000.0     10000.0      1  3.0  150.0      3
# ...        ...         ...    ...  ...    ...    ...
# 7319   25000.0     48587.0      1  8.0  150.0      5
# 7320   35000.0     60000.0      1  9.0  220.0      6
# 7321  450000.0      3430.0      1  4.0  750.0     14
# 7322  139000.0     21300.0      1  4.0  400.0      6
# 7323   80000.0      7127.0      1  5.0  220.0      6
#
# [7324 rows x 6 columns]

# %%
# Make sure to define or load 'df' before using it.
# Example: Load a DataFrame from a CSV file
# df = pd.read_csv('your_data.csv')

x = df.drop('price', axis=1) # type: ignore
y = df[['price']]
y
# Out:
#          price
# 0      35000.0
# 1     119900.0
# 2     600000.0
# 3      65000.0
# 4      80000.0
# ...        ...
# 7319   25000.0
# 7320   35000.0
# 7321  450000.0
# 7322  139000.0
# 7323   80000.0
#
# [7324 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train, y_test =train_test_split(x, y, random_state= 42, test_size=0.2)
x_train
# Out:
#       kms_driven  owner   age  power  brand
# 4506     68857.0      1  15.0  110.0      0
# 2758      5740.0      1   6.0  500.0      1
# 640      28329.0      1   6.0  110.0      5
# 5824     42966.0      1   7.0  150.0      3
# 6703      8000.0      1   5.0  500.0      1
# ...          ...    ...   ...    ...    ...
# 5191     56000.0      1   9.0  200.0      6
# 5226     22493.0      1   5.0  500.0      1
# 5390     17477.0      1   5.0  150.0      6
# 860      14836.0      1   8.0  150.0      3
# 7270      8000.0      1  10.0  250.0      4
#
# [5859 rows x 5 columns]

# %%
x_test
# Out:
#       kms_driven  owner   age  power  brand
# 3795     22500.0      1   6.0  350.0      1
# 1562      3198.0      1   5.0  500.0      1
# 4480     15000.0      1   6.0  220.0      6
# 3718     27000.0      1  12.0  150.0      3
# 5887     16764.0      1   9.0  100.0      5
# ...          ...    ...   ...    ...    ...
# 4417     16523.0      1   5.0  750.0     14
# 527       2881.0      1   7.0  250.0     13
# 3309     23833.0      1   4.0  150.0      7
# 5077      9282.0      1   7.0  500.0      1
# 565       2980.0      1   6.0  160.0      0
#
# [1465 rows x 5 columns]

# %%
y_test
# Out:
#          price
# 3795   88400.0
# 1562  102850.0
# 4480   67000.0
# 3718   30000.0
# 5887   20000.0
# ...        ...
# 4417  395000.0
# 527   140000.0
# 3309   54500.0
# 5077  114000.0
# 565    36000.0
#
# [1465 rows x 1 columns]

# %%
y_train
# Out:
#          price
# 4506   18000.0
# 2758  140000.0
# 640    32000.0
# 5824   40000.0
# 6703  160000.0
# ...        ...
# 5191   48928.0
# 5226  114000.0
# 5390   41000.0
# 860    40000.0
# 7270   80000.0
#
# [5859 rows x 1 columns]

# %%
y_train.shape, x_train.shape , x_test.shape, y_test.shape
# Out:
# ((5859, 1), (5859, 5), (1465, 5), (1465, 1))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression
# Instantiate the LinearRegression model
lr = LinearRegression()
lr
# Out:
# LinearRegression()

# %%
x_train.shape
# Out:
# (5859, 5)

# %%
y_train.shape
# Out:
# (5859, 1)

# %%
# Score the already instantiated LinearRegression model on the training set
lr.fit(x_train, y_train)
lr.score(x_train, y_train)
# Out:
# 0.7053826605671762

# %%
# Fit the model if not already fitted
lr.fit(x_train, y_train)
lr.score(x_test, y_test)
# Out:
# 0.7586900869386206

# %%
# Predict prices for the training set
lr.predict(x_train)
# Out:
# array([[-56720.62686909],
#        [212683.20959755],
#        [ 23791.81811851],
#        ...,
#        [ 60210.48494031],
#        [ 22702.41744365],
#        [ 82553.52111097]], shape=(5859, 1))

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\HP\AppData\Local\Packages\5319275A.51895FA4EA97F_cv1g1gvanyjgm\LocalState\sessions\01A1B9BDB8A069AEFD8D2D9C9DFA298DF7304A02\transfers\2025-27\laptopPrice.csv")
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression
# Instantiate the LinearRegression model
lr = LinearRegression()
lr
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# Prepare features and target
x = df.drop('Price', axis=1)
y = df[['Price']]

# Split the data
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42, test_size=0.2)

x_train.shape
# Out:
# (658, 18)

# %%
x_train
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 239    ASUS           Intel        Core i5            11th  16 GB     DDR4
# 707    acer             AMD        Ryzen 5   Not Available   4 GB     DDR4
# 759    ASUS             AMD        Ryzen 7   Not Available   4 GB     DDR4
# 432    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 299    ASUS           Intel        Core i5            11th   8 GB  LPDDR4X
# ..      ...             ...            ...             ...    ...      ...
# 71   Lenovo           Intel        Core i3            11th   4 GB     DDR4
# 106      HP           Intel        Core i3            11th   8 GB     DDR4
# 270  Lenovo           Intel        Core i5            11th   8 GB     DDR4
# 435     MSI           Intel        Core i5            10th   8 GB   LPDDR4
# 102    ASUS           Intel        Core i3            11th   8 GB     DDR4
#
#         ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
# One-hot encode categorical variables
x_train_encoded = pd.get_dummies(x_train)
y_train_array = y_train.values.ravel()  # Flatten y_train to 1D array

svg = SVR()
svg.fit(x_train_encoded, y_train_array)
# Out:
# SVR()

# %%
svg.fit(x_train, y_train)
# Out:
# SVR()

# %%
svg.score(x_train_encoded, y_train_array)
# Out:
# -0.06482137007973421

# %%
# Convert x_test to DataFrame with the same columns as x_train before encoding
x_test_df = pd.DataFrame(x_test, columns=x_train_encoded.columns[:x_test.shape[1]])

# One-hot encode x_test_df to match x_train_encoded columns
x_test_encoded = pd.get_dummies(x_test_df)
x_test_encoded = x_test_encoded.reindex(columns=x_train_encoded.columns, fill_value=0)

# Flatten y_test if needed
y_test_array = y_test.ravel() if hasattr(y_test, 'ravel') else y_test

svg.score(x_test_encoded, y_test_array)
# Out:
# -6043233349.049032

# %%
from sklearn.svm import SVC
svc_obj = SVC()
from sklearn.datasets import load_iris
x, y = load_iris(return_X_y=True)
from sklearn.model_selection import train_test_split
x_train , x_test, y_train , y_test = train_test_split(x, y , random_state=42 , test_size=0.2)
svc_obj.fit(x_train , y_train)
svc_obj.score(x_train, y_train)
svc_obj.score(x_test, y_test)
# Out:
# 1.0

# %%
svc_obj.predict(x_test)
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0])

# %%
y_test
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0])

# %%
##knn
from sklearn.neighbors import KNeighborsClassifier
knn_obj = KNeighborsClassifier()
knn_obj.fit(x_train, y_train)
knn_obj.score(x_train, y_train)
knn_obj.score(x_test, y_test)
# Out:
# 1.0

# %%
knn_obj.score(x_train, y_train)
# Out:
# 0.9666666666666667

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
knn_obj.score(x_train, y_train)
# Out:
# 0.9666666666666667

# %%
knn_obj.score(x_test, y_test)
# Out:
# 1.0
