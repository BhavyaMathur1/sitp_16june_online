# %% [markdown]
# 4123
# 02 ## pip install pandas

# %%
# %pip install pandas
import pandas as pd    ### pd is nick name for pandas, as pd and import keyword
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/25/ac/f6ee5250a8881b55bd3aecde9b8cfddea2f2b43e3588bca68a4e9aaf46c8/pandas-2.3.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/81/c4/34e93fe5f5429d7570ec1fa436f1986fb1f00c3e0f43a589fe2bbcd22c3f/pytz-2025.2-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for tzdata>=2022.7 from https://files.pythonhosted.org/packages/5c/23/c7abc0ca0a1526a0774eca151daeb8de62ec457e77262b66b359c3c7679e/tzdata-2025.2-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.1 MB 2.0 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/11.1 MB 6.3 MB/s eta 0:00:02
# ...

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\HP\AppData\Local\Packages\5319275A.51895FA4EA97F_cv1g1gvanyjgm\LocalState\shared\transfers\2025-26\Used_Bikes.csv")
# path = r"C:\Users\HP\AppData\Local\Packages\5319275A.51895FA4EA97F_cv1g1gvanyjgm\LocalState\shared\transfers\2025-26\Used_Bikes.csv"

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head()  ### first 5 rows
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.head(10)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
df.tail()  ### last 5 rows
# Out:
#                        bike_name    price    city  kms_driven        owner  \
# 32643     Hero Passion Pro 100cc  39000.0   Delhi     22000.0  First Owner
# 32644       TVS Apache RTR 180cc  30000.0  Karnal      6639.0  First Owner
# 32645   Bajaj Avenger Street 220  60000.0   Delhi     20373.0  First Owner
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur     84186.0  First Owner
# 32647         Bajaj Pulsar 150cc  22000.0    Pune     60857.0  First Owner
#
#         age  power  brand
# 32643   4.0  100.0   Hero
# 32644   9.0  180.0    TVS
# 32645   6.0  220.0  Bajaj
# 32646  16.0  125.0   Hero
# 32647  13.0  150.0  Bajaj

# %%
df.info()  ### information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df.duplicated()  ### check for duplicate rows
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643     True
# 32644     True
# 32645     True
# 32646     True
# 32647     True
# Length: 32648, dtype: bool

# %%
df.duplicated().sum()  ### check for duplicate rows
# Out:
# np.int64(25324)

# %%
df.shape
df.columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='object')

# %%
df.drop_duplicates(inplace=True)  ### drop duplicate rows
df.duplicated().sum()  ### check for duplicate rows after dropping

df.shape  ### check shape after dropping duplicates
# Out:
# (7324, 8)

# %%
df.isnull().sum()  ### check for null values
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df.dropna(inplace=True)  ### drop rows with null values
df.isnull().sum()  ### check for null values after dropping
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.describe()  ### statistical summary of the dataframe
# Out:
#               price     kms_driven          age        power
# count  7.324000e+03    7324.000000  7324.000000  7324.000000
# mean   8.488390e+04   23910.496587     6.656472   228.133397
# std    1.209662e+05   27317.594631     3.605299   158.324219
# min    4.400000e+03       1.000000     1.000000   100.000000
# 25%    3.000000e+04   10155.750000     4.000000   125.000000
# 50%    5.500000e+04   19000.000000     6.000000   160.000000
# 75%    1.000000e+05   30112.000000     8.000000   350.000000
# max    1.900000e+06  750000.000000    63.000000  1800.000000

# %%
df.dtypes
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
df["bike_name"]
# Out:
# 0         TVS Star City Plus Dual Tone 110cc
# 1                Royal Enfield Classic 350cc
# 2                       Triumph Daytona 675R
# 3                       TVS Apache RTR 180cc
# 4       Yamaha FZ S V 2.0 150cc-Ltd. Edition
#                         ...
# 9362               Hero Hunk Rear Disc 150cc
# 9369                     Bajaj Avenger 220cc
# 9370          Harley-Davidson Street 750 ABS
# 9371                   Bajaj Dominar 400 ABS
# 9372                Bajaj Avenger Street 220
# Name: bike_name, Length: 7324, dtype: object

# %%
df["brand"]
# Out:
# 0                   TVS
# 1         Royal Enfield
# 2               Triumph
# 3                   TVS
# 4                Yamaha
#              ...
# 9362               Hero
# 9369              Bajaj
# 9370    Harley-Davidson
# 9371              Bajaj
# 9372              Bajaj
# Name: brand, Length: 7324, dtype: object

# %%
df['brand'].unique()  ### unique values in the 'brand' column
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
df['brand'].value_counts()  ### count of unique values in the 'brand' column
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
df['owner'].value_counts()  ### count of unique values in the 'owner' column
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
df['age'].value_counts()  ### count of unique values in the 'age' column
# Out:
# age
# 5.0     1211
# 4.0     1083
# 6.0      901
# 3.0      749
# 7.0      742
# 8.0      576
# 9.0      476
# 10.0     372
# 2.0      296
# 11.0     285
# 12.0     182
# 13.0     135
# 14.0      91
# 15.0      69
# 16.0      57
# 17.0      30
# 18.0      20
# 1.0        9
# 24.0       7
# 19.0       6
# 20.0       4
# 39.0       3
# 25.0       3
# 37.0       2
# 41.0       2
# 27.0       2
# 23.0       2
# 43.0       2
# 30.0       1
# 63.0       1
# 38.0       1
# 34.0       1
# 31.0       1
# 22.0       1
# 26.0       1
# Name: count, dtype: int64

# %%
df.drop(['bike_name', 'city'], axis=1, inplace=True, errors='ignore')  ### drop columns if they exist, ignore if not
df
# Out:
#          price  kms_driven        owner  age  power            brand
# 0      35000.0     17654.0  First Owner  3.0  110.0              TVS
# 1     119900.0     11000.0  First Owner  4.0  350.0    Royal Enfield
# 2     600000.0       110.0  First Owner  8.0  675.0          Triumph
# 3      65000.0     16329.0  First Owner  4.0  180.0              TVS
# 4      80000.0     10000.0  First Owner  3.0  150.0           Yamaha
# ...        ...         ...          ...  ...    ...              ...
# 9362   25000.0     48587.0  First Owner  8.0  150.0             Hero
# 9369   35000.0     60000.0  First Owner  9.0  220.0            Bajaj
# 9370  450000.0      3430.0  First Owner  4.0  750.0  Harley-Davidson
# 9371  139000.0     21300.0  First Owner  4.0  400.0            Bajaj
# 9372   80000.0      7127.0  First Owner  5.0  220.0            Bajaj
#
# [7324 rows x 6 columns]

# %%
cat_col = df.select_dtypes(include=['object'])  ### select columns with object data type
cat_col
# Out:
#                 brand
# 0                 TVS
# 1       Royal Enfield
# 2             Triumph
# 3                 TVS
# 4              Yamaha
# ...               ...
# 9362             Hero
# 9369            Bajaj
# 9370  Harley-Davidson
# 9371            Bajaj
# 9372            Bajaj
#
# [7324 rows x 1 columns]

# %%
# Reload the DataFrame from the original CSV to restore all columns
df = pd.read_csv(r"C:\Users\HP\AppData\Local\Packages\5319275A.51895FA4EA97F_cv1g1gvanyjgm\LocalState\shared\transfers\2025-26\Used_Bikes.csv")

# %%
# Add a new 'owner' column with a default value
if 'df' in locals():
	df['owner'] = 'Unknown'  # or any value/list you want
else:
	print("DataFrame 'df' is not defined. Please run the cell where df is created.")
# Out:
# DataFrame 'df' is not defined. Please run the cell where df is created.

# %%
num_col =df.select_dtypes(exclude=['object'])  ### select columns with non-object data type
num_col
# Out:
#          price  kms_driven  age  power
# 0      35000.0     17654.0  3.0  110.0
# 1     119900.0     11000.0  4.0  350.0
# 2     600000.0       110.0  8.0  675.0
# 3      65000.0     16329.0  4.0  180.0
# 4      80000.0     10000.0  3.0  150.0
# ...        ...         ...  ...    ...
# 9362   25000.0     48587.0  8.0  150.0
# 9369   35000.0     60000.0  9.0  220.0
# 9370  450000.0      3430.0  4.0  750.0
# 9371  139000.0     21300.0  4.0  400.0
# 9372   80000.0      7127.0  5.0  220.0
#
# [7324 rows x 4 columns]

# %%
#bike_brand = 'tvs'  ### unique values in the 'brand' column
#km = 50000
#price = 50000

tvs_df = df[df['brand']== 'TVS']

# %%
tvs_under_50k = tvs_df[tvs_df['price']==50000]
tvs_under_50k
# Out:
#         price  kms_driven  age  power brand
# 3905  50000.0     22932.0  9.0  160.0   TVS
# 3906  50000.0     18229.0  5.0  160.0   TVS
# 6723  50000.0     20712.0  4.0  160.0   TVS
# 8917  50000.0     14818.0  6.0  160.0   TVS

# %%
brand = 'Royal Enfield'
price = 100000
km = 50000
owner = 'First Owner'

# %%
df['brand'].unique()  ### unique values in the 'brand' column
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
royal_df=df[df['brand']=='Royal Enfield']
royal_under100k=royal_df[royal_df['price']==100000]
royal_under100k
# Out:
#          price  kms_driven   age  power          brand
# 159   100000.0     30294.0   5.0  350.0  Royal Enfield
# 266   100000.0     25000.0   8.0  500.0  Royal Enfield
# 761   100000.0     48000.0  12.0  500.0  Royal Enfield
# 1586  100000.0     18500.0   6.0  350.0  Royal Enfield
# 1721  100000.0     15500.0   8.0  500.0  Royal Enfield
# 1784  100000.0     59000.0   7.0  350.0  Royal Enfield
# 2022  100000.0      7000.0   5.0  350.0  Royal Enfield
# 2280  100000.0     33500.0   5.0  350.0  Royal Enfield
# 2443  100000.0     46000.0   7.0  350.0  Royal Enfield
# 2520  100000.0     22000.0   7.0  500.0  Royal Enfield
# 2565  100000.0     25555.0   5.0  350.0  Royal Enfield
# 2566  100000.0     39645.0   6.0  350.0  Royal Enfield
# 2646  100000.0     40000.0   6.0  350.0  Royal Enfield
# 2727  100000.0     14576.0   6.0  350.0  Royal Enfield
# 2752  100000.0     11937.0   4.0  350.0  Royal Enfield
# 2860  100000.0     60000.0   4.0  350.0  Royal Enfield
# ...

# %%
royal_name = df[df['brand'] == "Royal Enfield"]
royal_name

royal_price = df[df['price'] == 100000]
royal_price

royal_kms = df[df['kms_driven'] == 50000]
royal_kms

# royal_owner = df[df['owner'] == "First Owner"]
# royal_owner
# Out:
#          price  kms_driven   age  power          brand
# 229    30000.0     50000.0   6.0  150.0         Yamaha
# 679    16000.0     50000.0   9.0  100.0           Hero
# 754    21000.0     50000.0  10.0  150.0           Hero
# 890    33000.0     50000.0   9.0  125.0          Bajaj
# 924    72000.0     50000.0   4.0  220.0          Bajaj
# 970    18000.0     50000.0  17.0  100.0          Bajaj
# 1224   28000.0     50000.0   7.0  180.0            TVS
# 1419   75000.0     50000.0   7.0  350.0  Royal Enfield
# 1468   50000.0     50000.0   7.0  150.0         Yamaha
# 2050  130000.0     50000.0   5.0  500.0  Royal Enfield
# 2213   23000.0     50000.0  11.0  100.0           Hero
# 2278   40000.0     50000.0  12.0  150.0         Yamaha
# 2621   30000.0     50000.0   8.0  150.0          Honda
# 2827   43999.0     50000.0   8.0  200.0          Bajaj
# 2839   54500.0     50000.0   8.0  150.0         Yamaha
# 2863   14000.0     50000.0  12.0  150.0          Bajaj
# ...

# %%
royal_df = df[(df['brand'] == 'Royal Enfield') &
              (df['price'] == price) &
              (df['kms_driven'] <= km) &
              (df['owner'] == owner)]

royal_df
# Out:
# Empty DataFrame
# Columns: [bike_name, price, city, kms_driven, owner, age, power, brand]
# Index: []

# %%
price = 100000
km = 50000
owner = 'First Owner'

bike = df[(df['brand'] == 'Royal Enfield') &
          (df['price'] <= price) &
          (df['kms_driven'] <= km) &
          (df['owner'] == owner)]
bike
# Out:
#          price  kms_driven        owner   age  power          brand
# 36     98800.0     39000.0  First Owner   5.0  350.0  Royal Enfield
# 40     70000.0     45000.0  First Owner   8.0  350.0  Royal Enfield
# 42     78000.0      8500.0  First Owner  13.0  350.0  Royal Enfield
# 44     85000.0     18000.0  First Owner   6.0  350.0  Royal Enfield
# 46     55346.0     38000.0  First Owner  10.0  350.0  Royal Enfield
# ...        ...         ...          ...   ...    ...            ...
# 32582  95500.0     18000.0  First Owner   8.0  350.0  Royal Enfield
# 32595  87000.0     16336.0  First Owner   7.0  350.0  Royal Enfield
# 32601  95500.0     18000.0  First Owner   8.0  350.0  Royal Enfield
# 32633  87000.0     16336.0  First Owner   7.0  350.0  Royal Enfield
# 32639  95500.0     18000.0  First Owner   8.0  350.0  Royal Enfield
#
# [1760 rows x 6 columns]

# %%
df.query("brand == 'Royal Enfield' and price == 100000 and kms_driven <= 50000 and owner == 'First Owner'")
# Out:
#          price  kms_driven        owner   age  power          brand
# 159   100000.0     30294.0  First Owner   5.0  350.0  Royal Enfield
# 266   100000.0     25000.0  First Owner   8.0  500.0  Royal Enfield
# 299   100000.0     25000.0  First Owner   8.0  500.0  Royal Enfield
# 761   100000.0     48000.0  First Owner  12.0  500.0  Royal Enfield
# 834   100000.0     48000.0  First Owner  12.0  500.0  Royal Enfield
# 1586  100000.0     18500.0  First Owner   6.0  350.0  Royal Enfield
# 1721  100000.0     15500.0  First Owner   8.0  500.0  Royal Enfield
# 2022  100000.0      7000.0  First Owner   5.0  350.0  Royal Enfield
# 2280  100000.0     33500.0  First Owner   5.0  350.0  Royal Enfield
# 2443  100000.0     46000.0  First Owner   7.0  350.0  Royal Enfield
# 2520  100000.0     22000.0  First Owner   7.0  500.0  Royal Enfield
# 2566  100000.0     39645.0  First Owner   6.0  350.0  Royal Enfield
# 2646  100000.0     40000.0  First Owner   6.0  350.0  Royal Enfield
# ...

# %%
#encodding 
import pandas as pd

df = pd.read_csv(r"C:\Users\HP\AppData\Local\Packages\5319275A.51895FA4EA97F_cv1g1gvanyjgm\LocalState\shared\transfers\2025-26\Used_Bikes.csv")
df.dtypes
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
df.drop(['bike_name', 'city'], axis=1, inplace=True, errors='ignore')  ### drop columns if they exist, ignore if not
df
# Out:
#           price  kms_driven        owner   age  power          brand
# 0       35000.0     17654.0  First Owner   3.0  110.0            TVS
# 1      119900.0     11000.0  First Owner   4.0  350.0  Royal Enfield
# 2      600000.0       110.0  First Owner   8.0  675.0        Triumph
# 3       65000.0     16329.0  First Owner   4.0  180.0            TVS
# 4       80000.0     10000.0  First Owner   3.0  150.0         Yamaha
# ...         ...         ...          ...   ...    ...            ...
# 32643   39000.0     22000.0  First Owner   4.0  100.0           Hero
# 32644   30000.0      6639.0  First Owner   9.0  180.0            TVS
# 32645   60000.0     20373.0  First Owner   6.0  220.0          Bajaj
# 32646   15600.0     84186.0  First Owner  16.0  125.0           Hero
# 32647   22000.0     60857.0  First Owner  13.0  150.0          Bajaj
#
# [32648 rows x 6 columns]

# %%
df['owner'].unique()  ### unique values in the 'owner' column
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth Owner Or More'], dtype=object)

# %%
owner_dict = {'First Owner': 0,'Second Owner': 1,'Third Owner': 2, 'Fourth & Above Owner': 3}
df['owner'] = df['owner'].map(owner_dict)  ### map the 'owner' column to numerical values
df.dtypes
# Out:
# price         float64
# kms_driven    float64
# owner         float64
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
df['brand'].unique()  ### unique values in the 'brand' column
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
brand_dict = {'TVS':0, 'Royal Enfield':1, 'Triumph':2, 'Yamaha':3, 'Honda':4, 'Hero':5,
       'Bajaj':6, 'Suzuki':7, 'Benelli':8, 'KTM':9, 'Mahindra':10, 'Kawasaki':11,
       'Ducati':12, 'Hyosung':13, 'Harley-Davidson':14, 'Jawa':15, 'BMW':16, 'Indian':17,
       'Rajdoot':18, 'LML':19, 'Yezdi':20, 'MV':21, 'Ideal':22}
df['brand'] = df['brand'].map(brand_dict)  ### map the 'brand' column to numerical values
df.dtypes
# Out:
# price         float64
# kms_driven    float64
# owner         float64
# age           float64
# power         float64
# brand           int64
# dtype: object

# %%
# It looks like you want to save the cleaned DataFrame to a CSV file.
# Use the to_csv method of the DataFrame, e.g.:
if 'df' in locals():
	df.to_csv('cleaned_bikes.csv', index=False)
else:
	print("DataFrame 'df' is not defined. Please run the cell where df is created.")
# Out:
# DataFrame 'df' is not defined. Please run the cell where df is created.

# %%
df.to_csv("cleaned_bike_dataset.csv")

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\HP\AppData\Local\Packages\5319275A.51895FA4EA97F_cv1g1gvanyjgm\LocalState\sessions\01A1B9BDB8A069AEFD8D2D9C9DFA298DF7304A02\transfers\2025-27\laptopPrice.csv")
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.to_csv("cleaned_laptopPrice_dataset.csv")
